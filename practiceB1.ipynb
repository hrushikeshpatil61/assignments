# %%
import pandas as pd
import numpy as np

# %% [markdown]
# df = pd.read_csv('/content/sample_data/dataset_Facebook.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of     Page total likes;Type;Category;Post Month;Post Weekday;Post Hour;Paid;Lifetime Post Total Reach;Lifetime Post Total Impressions;Lifetime Engaged Users;Lifetime Post Consumers;Lifetime Post Consumptions;Lifetime Post Impressions by people who have liked your Page;Lifetime Post reach by people who like your Page;Lifetime People who have liked your Page and engaged with your post;comment;like;share;Total Interactions
# 0    139441;Photo;2;12;4;3;0;2752;5091;178;109;159;...
# 1    139441;Status;2;12;3;10;0;10460;19057;1457;136...
# 2    139441;Photo;3;12;3;3;0;2413;4373;177;113;154;...
# 3    139441;Photo;2;12;2;10;1;50128;87991;2211;790;...
# 4    139441;Photo;2;12;2;3;0;7244;13594;671;410;580...
# ..                                                 ...
# 495  85093;Photo;3;1;7;2;0;4684;7536;733;708;985;47...
# 496  81370;Photo;2;1;5;8;0;3480;6229;537;508;687;39...
# 497  81370;Photo;1;1;5;2;0;3778;7216;625;572;795;47...
# ...

# %%
df.shape
# Out:
# (500, 1)

# %%
df = pd.read_csv('/content/sample_data/dataset_Facebook.csv',delimiter=';')

# %%
df.head
# Out:
# <bound method NDFrame.head of      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df = pd.read_csv("/content/sample_data/dataset_Facebook.csv",delimiter=';')
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
sb1 = df.loc[5:50,['Type','Post Weekday','Post Hour','like','share']]
sb1
# Out:
#       Type  Post Weekday  Post Hour   like  share
# 5   Status             1          9  152.0   33.0
# 6    Photo             1          3  249.0   27.0
# 7    Photo             7          9  325.0   14.0
# 8   Status             7          3  161.0   31.0
# 9    Photo             6         10  113.0   26.0
# 10  Status             5         10  233.0   19.0
# 11   Photo             5         10   88.0   18.0
# 12   Photo             5         10   90.0   14.0
# 13   Photo             5          3  137.0   10.0
# 14   Photo             4          5  577.0   20.0
# 15  Status             3         10   86.0   18.0
# 16   Photo             3          3   40.0   12.0
# 17   Photo             2         12  678.0   20.0
# 18  Status             2          3   54.0   17.0
# 19   Photo             1         11   34.0    8.0
# 20   Photo             1          3   66.0   12.0
# 21   Photo             7         10    0.0    0.0
# 22    Link             7         10   16.0    2.0
# ...

# %%
sb2 = df.loc[0:3,['Type','like','share']]
sb2
# Out:
#      Type    like  share
# 0   Photo    79.0   17.0
# 1  Status   130.0   29.0
# 2   Photo    66.0   14.0
# 3   Photo  1572.0  147.0

# %%
mg1 = pd.merge(sb1,sb2,on='Type')
mg1
# Out:
#       Type  Post Weekday  Post Hour  like_x  share_x  like_y  share_y
# 0   Status             1          9   152.0     33.0   130.0     29.0
# 1   Status             7          3   161.0     31.0   130.0     29.0
# 2   Status             5         10   233.0     19.0   130.0     29.0
# 3   Status             3         10    86.0     18.0   130.0     29.0
# 4   Status             2          3    54.0     17.0   130.0     29.0
# ..     ...           ...        ...     ...      ...     ...      ...
# 90   Photo             2         11    77.0     15.0    66.0     14.0
# 91   Photo             2         11    77.0     15.0  1572.0    147.0
# 92   Photo             1          9    48.0      9.0    79.0     17.0
# 93   Photo             1          9    48.0      9.0    66.0     14.0
# 94   Photo             1          9    48.0      9.0  1572.0    147.0
#
# [95 rows x 7 columns]

# %%
st1 = df.sort_values(by='Page total likes')
st1.head()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 499             81370  Photo         2           1             4          4
# 496             81370  Photo         2           1             5          8
# 498             81370  Photo         3           1             4         11
# 497             81370  Photo         1           1             5          2
# 493             85093  Photo         3           1             1          2
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 499   NaN                       4188                             7292
# 496   0.0                       3480                             6229
# 498   0.0                       4156                             7564
# 497   0.0                       3778                             7216
# 493   0.0                       8412                            13960
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
tp1 = sb1.transpose()
tp1
# Out:
#                   5      6      7       8      9       10     11     12  \
# Type          Status  Photo  Photo  Status  Photo  Status  Photo  Photo
# Post Weekday       1      1      7       7      6       5      5      5
# Post Hour          9      3      9       3     10      10     10     10
# like           152.0  249.0  325.0   161.0  113.0   233.0   88.0   90.0
# share           33.0   27.0   14.0    31.0   26.0    19.0   18.0   14.0
#
#                  13     14  ...     41     42    43     44    45      46  \
# Type          Photo  Photo  ...   Link  Photo  Link  Photo  Link  Status
# Post Weekday      5      4  ...      6      5     5      4     4       3
# Post Hour         3      5  ...      3     10     3     11     3      11
# like          137.0  577.0  ...  187.0   26.0  29.0   47.0  57.0   174.0
# share          10.0   20.0  ...   18.0    3.0  10.0   11.0  10.0    36.0
#
#                 47     48    49     50
# Type          Link  Photo  Link  Photo
# ...

# %%
sb1.melt()
# Out:
#     variable   value
# 0       Type  Status
# 1       Type   Photo
# 2       Type   Photo
# 3       Type  Status
# 4       Type   Photo
# ..       ...     ...
# 225    share    36.0
# 226    share     8.0
# 227    share    15.0
# 228    share     1.0
# 229    share     9.0
#
# [230 rows x 2 columns]
