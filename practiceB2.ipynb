# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/sample_data/airquality.csv")
df.head()
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 0   41.0    190.0   7.4    67      5    1
# 1   36.0    118.0   8.0    72      5    2
# 2   12.0    149.0  12.6    74      5    3
# 3   18.0    313.0  11.5    62      5    4
# 4    NaN      NaN  14.3    56      5    5

# %%
df.tail()
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 148   30.0    193.0   6.9    70      9   26
# 149    NaN    145.0  13.2    77      9   27
# 150   14.0    191.0  14.3    75      9   28
# 151   18.0    131.0   8.0    76      9   29
# 152   20.0    223.0  11.5    68      9   30

# %%
df.isnull().sum()
# Out:
# Ozone      37
# Solar.R     7
# Wind        0
# Temp        0
# Month       0
# Day         0
# dtype: int64

# %%
df["Ozone"].fillna(df["Ozone"].mean(),inplace=True)
df.isnull().sum()
# Out:
# Ozone      0
# Solar.R    7
# Wind       0
# Temp       0
# Month      0
# Day        0
# dtype: int64

# %%
df["Solar.R"].fillna(df["Solar.R"].mean(),inplace=True)
df.isnull().sum()
# Out:
# Ozone      0
# Solar.R    0
# Wind       0
# Temp       0
# Month      0
# Day        0
# dtype: int64

# %%
df["new solar"]=[True if x1>100 else False for x1 in df['Solar.R']]

# %%
df.head(30)
# Out:
#         Ozone     Solar.R  Wind  Temp  Month  Day  new solar
# 0    41.00000  190.000000   7.4    67      5    1       True
# 1    36.00000  118.000000   8.0    72      5    2       True
# 2    12.00000  149.000000  12.6    74      5    3       True
# 3    18.00000  313.000000  11.5    62      5    4       True
# 4    42.12931  185.931507  14.3    56      5    5       True
# 5    28.00000  185.931507  14.9    66      5    6       True
# 6    23.00000  299.000000   8.6    65      5    7       True
# 7    19.00000   99.000000  13.8    59      5    8      False
# 8     8.00000   19.000000  20.1    61      5    9      False
# 9    42.12931  194.000000   8.6    69      5   10       True
# 10    7.00000  185.931507   6.9    74      5   11       True
# 11   16.00000  256.000000   9.7    69      5   12       True
# 12   11.00000  290.000000   9.2    66      5   13       True
# 13   14.00000  274.000000  10.9    68      5   14       True
# ...

# %%
df["condition"]=["cold" if x>65 else "Hot" for x in df["Temp"]]
df.head(20)
# Out:
#        Ozone     Solar.R  Wind  Temp  Month  Day  new solar condition
# 0   41.00000  190.000000   7.4    67      5    1       True      cold
# 1   36.00000  118.000000   8.0    72      5    2       True      cold
# 2   12.00000  149.000000  12.6    74      5    3       True      cold
# 3   18.00000  313.000000  11.5    62      5    4       True       Hot
# 4   42.12931  185.931507  14.3    56      5    5       True       Hot
# 5   28.00000  185.931507  14.9    66      5    6       True      cold
# 6   23.00000  299.000000   8.6    65      5    7       True       Hot
# 7   19.00000   99.000000  13.8    59      5    8      False       Hot
# 8    8.00000   19.000000  20.1    61      5    9      False       Hot
# 9   42.12931  194.000000   8.6    69      5   10       True      cold
# 10   7.00000  185.931507   6.9    74      5   11       True      cold
# 11  16.00000  256.000000   9.7    69      5   12       True      cold
# ...

# %%
data2 = pd.read_csv("/content/sample_data/airquality.csv")

# %%
data2.head(40)
# Out:
#     Ozone  Solar.R  Wind  Temp  Month  Day
# 0    41.0    190.0   7.4    67      5    1
# 1    36.0    118.0   8.0    72      5    2
# 2    12.0    149.0  12.6    74      5    3
# 3    18.0    313.0  11.5    62      5    4
# 4     NaN      NaN  14.3    56      5    5
# 5    28.0      NaN  14.9    66      5    6
# 6    23.0    299.0   8.6    65      5    7
# 7    19.0     99.0  13.8    59      5    8
# 8     8.0     19.0  20.1    61      5    9
# 9     NaN    194.0   8.6    69      5   10
# 10    7.0      NaN   6.9    74      5   11
# 11   16.0    256.0   9.7    69      5   12
# 12   11.0    290.0   9.2    66      5   13
# 13   14.0    274.0  10.9    68      5   14
# 14   18.0     65.0  13.2    58      5   15
# 15   14.0    334.0  11.5    64      5   16
# 16   34.0    307.0  12.0    66      5   17
# 17    6.0     78.0  18.4    57      5   18
# 18   30.0    322.0  11.5    68      5   19
# 19   11.0     44.0   9.7    62      5   20
# 20    1.0      8.0   9.7    59      5   21
# ...

# %%
var=[0,50,100,150,200,250,300,350]
data2['Ozone']=pd.cut(data2['Ozone'],bins=var)

# %%
data2.head(40)
# Out:
#              Ozone  Solar.R  Wind  Temp  Month  Day
# 0      (0.0, 50.0]    190.0   7.4    67      5    1
# 1      (0.0, 50.0]    118.0   8.0    72      5    2
# 2      (0.0, 50.0]    149.0  12.6    74      5    3
# 3      (0.0, 50.0]    313.0  11.5    62      5    4
# 4              NaN      NaN  14.3    56      5    5
# 5      (0.0, 50.0]      NaN  14.9    66      5    6
# 6      (0.0, 50.0]    299.0   8.6    65      5    7
# 7      (0.0, 50.0]     99.0  13.8    59      5    8
# 8      (0.0, 50.0]     19.0  20.1    61      5    9
# 9              NaN    194.0   8.6    69      5   10
# 10     (0.0, 50.0]      NaN   6.9    74      5   11
# 11     (0.0, 50.0]    256.0   9.7    69      5   12
# 12     (0.0, 50.0]    290.0   9.2    66      5   13
# 13     (0.0, 50.0]    274.0  10.9    68      5   14
# 14     (0.0, 50.0]     65.0  13.2    58      5   15
# 15     (0.0, 50.0]    334.0  11.5    64      5   16
# 16     (0.0, 50.0]    307.0  12.0    66      5   17
# ...

# %%
data = pd.read_csv("/content/sample_data/airquality.csv")
data.head(10)
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 0   41.0    190.0   7.4    67      5    1
# 1   36.0    118.0   8.0    72      5    2
# 2   12.0    149.0  12.6    74      5    3
# 3   18.0    313.0  11.5    62      5    4
# 4    NaN      NaN  14.3    56      5    5
# 5   28.0      NaN  14.9    66      5    6
# 6   23.0    299.0   8.6    65      5    7
# 7   19.0     99.0  13.8    59      5    8
# 8    8.0     19.0  20.1    61      5    9
# 9    NaN    194.0   8.6    69      5   10

# %%
from sklearn import linear_model
x=df[['Ozone']]
y=df[['Temp']]

# %%
reg=linear_model.LinearRegression()
model = reg.fit(x,y)

# %%
y_pred=model.predict(x)
print("predicted",y_pred,"\n")
# Out:
# predicted [[ 77.65557648]
#  [ 76.65152801]
#  [ 71.83209535]
#  [ 73.03695351]
#  [ 77.88235294]
#  [ 75.04505045]
#  [ 74.04100198]
#  [ 73.23776321]
#  [ 71.02885657]
#  [ 77.88235294]
#  [ 70.82804688]
#  [ 72.63533413]
#  [ 71.63128566]
#  [ 72.23371474]
#  [ 73.03695351]
#  [ 72.23371474]
#  [ 76.24990862]
#  [ 70.62723719]
#  [ 75.44666984]
#  [ 71.63128566]
#  [ 69.62318872]
#  [ 71.63128566]
#  [ 70.2256178 ]
#  [ 75.84828923]
#  [ 77.88235294]
#  [ 77.88235294]
#  [ 77.88235294]
#  [ 74.04100198]
#  [ 78.45881525]
#  [ 92.51549383]
#  [ 76.8523377 ]
#  [ 77.88235294]
#  [ 77.88235294]
#  [ 77.88235294]
#  [ 77.88235294]
#  [ 77.88235294]
#  [ 77.88235294]
#  [ 75.24586015]
#  [ 77.88235294]
#  [ 83.6798673 ]
#  [ 77.25395709]
#  [ 77.88235294]
#  [ 77.88235294]
#  [ 74.04100198]
#  [ 77.88235294]
#  [ 77.88235294]
#  [ 73.6393826 ]
#  [ 76.8523377 ]
#  [ 73.4385729 ]
#  [ 71.83209535]
#  [ 72.03290504]
#  [ 77.88235294]
#  [ 77.88235294]
#  [ 77.88235294]
#  [ 77.88235294]
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.scatter(x,y,color="red")
plt.plot(x,y_pred,color="green")
plt.xlabel("ozone")
plt.ylabel("Temp")
plt.show()
